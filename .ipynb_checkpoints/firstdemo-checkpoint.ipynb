# %%
import plotly.graph_objs as go
import pandas as pd
import numpy as np
import re

# %%
data1 = pd.read_csv('data/VMM1_1st_nil_DT9_peptide.csv')

# %%
x0 = data.Length

go.Histogram(
    x = x0
)
# fig.update_layout(
#     title_text='Sampled Results', # title of plot
#     xaxis_title_text='Value', # xaxis label
#     yaxis_title_text='Count', # yaxis label
#     bargap=0.2, # gap between bars of adjacent location coordinates
#     bargroupgap=0.1 # gap between bars of the same location coordinates
# )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-206-094fb397f91f> in <module>
#       2
#       3 go.Histogram(
# ----> 4     x = x0
#       5 ).plot()
#       6
#
# AttributeError: 'Histogram' object has no attribute 'plot'

# %%
def filterPeaksFile(data, dropPTM=True, minLen=1, maxLen=133):
    
#   Removing rows with no accession identity
    data = data.dropna(subset=['Accession'])
    
#   Dropping the peptides with Post translational modifications
    if dropPTM:
        data = data[data.apply(lambda x : re.search(r'[(].+[)]',x['Peptide']) == None,axis=1)]

#   Removing contamincation founf from accession number 
    data = data[data.apply(lambda x : str(x['Accession']).find('CONTAM') == -1,axis=1)]
    
#   Filtering on the basis of the peptide length
    data = data[data.apply(lambda x : x['Length'] in range(minLen,maxLen),axis=1)]
    
    return data

temp = filterPeaksFile(data1)

# %%
data1[data1.apply(lambda x : x['Length'] in range(1,9),axis=1)]
# Out:
#                Peptide  -10lgP      Mass  Length  ppm       m/z     RT  \
# 132           SSGPQRLV   42.69  842.4610       8  1.5  422.2384  27.71
# 166           NAYQHSKV   40.94  945.4668       8  2.3  473.7418  19.72
# 171           HSGPIHVL   40.64  858.4712       8  1.6  430.2436  29.60
# 189           HSFLHPSY   39.79  986.4610       8 -0.2  494.2377  33.07
# 197   YGM(+15.99)PRQIL   39.59  992.5113       8 -0.1  497.2628  36.00
# ...                ...     ...       ...     ...  ...       ...    ...
# 1352          SSVPGVRL   19.96  813.4708       8  1.8  407.7434  38.06
# 1354          AADGPRVF   19.95  831.4238       8  2.0  416.7200  35.88
# 1366          HSGPPIVI   19.78  818.4650       8 -0.6  410.2395  41.90
# 1382          DASLLKKV   19.61  872.5331       8  1.4  437.2744  32.20
# 1388          HGGPTRDL   19.56  851.4249       8  1.5  426.7204  21.14
#
#       Intensity VMM1_DT9_noIFN  Fraction   Scan  \
# 132                107000000.0       454   7146
# 166                  2000000.0       452   4564
# 171                  7650000.0       456   7272
# 189                  8380000.0       456   8416
# 197                 33200000.0       449   8894
# ...                        ...       ...    ...
# 1352                  476000.0       456  10046
# 1354                 1580000.0       455   9379
# 1366                 3230000.0       449  10917
# 1382                 1710000.0       456   8122
# 1388                47600000.0       453   4898
#
#                                        Source File  #Spec  \
# 132    20180801_QE2_SRABJMJT_VMM1_DT9_noIFN_A6.raw      4
# 166    20180801_QE2_SRABJMJT_VMM1_DT9_noIFN_A4.raw      1
# 171    20180801_QE2_SRABJMJT_VMM1_DT9_noIFN_A8.raw      1
# 189    20180801_QE2_SRABJMJT_VMM1_DT9_noIFN_A8.raw      2
# 197   20180801_QE2_SRABJMJT_VMM1_DT9_noIFN_A10.raw      1
# ...                                            ...    ...
# 1352   20180801_QE2_SRABJMJT_VMM1_DT9_noIFN_A8.raw      1
# 1354   20180801_QE2_SRABJMJT_VMM1_DT9_noIFN_A7.raw      1
# 1366  20180801_QE2_SRABJMJT_VMM1_DT9_noIFN_A10.raw      1
# 1382   20180801_QE2_SRABJMJT_VMM1_DT9_noIFN_A8.raw      1
# 1388   20180801_QE2_SRABJMJT_VMM1_DT9_noIFN_A5.raw      1
#
#       #Spec VMM1_DT9_noIFN                                          Accession  \
# 132                      4  Q8N511|TM199_HUMAN:J3KS81|J3KS81_HUMAN:J3KRW7|...
# 166                      1                                 P63172|DYLT1_HUMAN
# 171                      1  E5RHD4|E5RHD4_HUMAN:H0YBK0|H0YBK0_HUMAN:Q15329...
# 189                      2  P12757-5|SKIL_HUMAN:P12757|SKIL_HUMAN:P12757-3...
# 197                      1            P37802|TAGL2_HUMAN:P37802-2|TAGL2_HUMAN
# ...                    ...                                                ...
# 1352                     1                                  P08670|VIME_HUMAN
# 1354                     1  Q9Y285-2|SYFA_HUMAN:Q9Y285|SYFA_HUMAN:K7ER00|K...
# 1366                     1  Q6ZRI6-2|CO039_HUMAN:Q6ZRI6|CO039_HUMAN:H3BMJ2...
# 1382                     1  Q9UBB4-2|ATX10_HUMAN:Q9UBB4|ATX10_HUMAN:B1AHE3...
# 1388                     1                                 Q9UN79|SOX13_HUMAN
#
#                 PTM                    AScore
# 132             NaN                       NaN
# 166             NaN                       NaN
# 171             NaN                       NaN
# 189             NaN                       NaN
# 197   Oxidation (M)  M3:Oxidation (M):1000.00
# ...             ...                       ...
# 1352            NaN                       NaN
# 1354            NaN                       NaN
# 1366            NaN                       NaN
# 1382            NaN                       NaN
# 1388            NaN                       NaN
#
# [144 rows x 16 columns]

# %%
bool(' '.strip())
# Out:
# False

# %%
str('#CONTAM#P47597|CLPB_MYCGE').find('CONTAM')
# Out:
# -1
